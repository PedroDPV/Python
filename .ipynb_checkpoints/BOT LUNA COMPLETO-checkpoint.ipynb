# %%
import pyautogui
import time



#### BIBLIOTECA DE FUNÇÕES DO BOT ####
def removerheroinas():
    pyautogui.moveTo(784, 452),pyautogui.click(784, 452), time.sleep(1)  # remover heroinas
    pyautogui.moveTo(1095, 445),pyautogui.click(1095, 445), time.sleep(1)
    pyautogui.moveTo(1410, 451),pyautogui.click(1410, 451), time.sleep(1)


def selecionarboss():
    pyautogui.click(696, 395), time.sleep(1)
    pyautogui.click(886, 389), time.sleep(1)
    pyautogui.click(981, 394), time.sleep(1)
    pyautogui.click(1196, 397), time.sleep(1)
    pyautogui.click(1304, 390), time.sleep(1)
    pyautogui.click(1497, 403), time.sleep(1)
    pyautogui.click(722, 729), time.sleep(1)
    pyautogui.click(883, 710), time.sleep(1)
    pyautogui.click(1100, 700), time.sleep(1)
    pyautogui.click(1239, 707), time.sleep(1)
    pyautogui.click(1383, 706), time.sleep(1)
    pyautogui.click(1546, 702), time.sleep(1)
    
def time1():
    pyautogui.moveTo(629, 565),pyautogui.click(629, 565), time.sleep(4)  # abrir aba
    pyautogui.moveTo(423, 408), pyautogui.click(423, 408), time.sleep(2)  # selecionar time 1
    pyautogui.moveTo(556, 429), pyautogui.click(556, 429), time.sleep(2)
    pyautogui.moveTo(672, 418), pyautogui.click(672, 418), time.sleep(2)
    pyautogui.moveTo(876, 562),pyautogui.click(876, 562), time.sleep(2)  # fechar aba
    pyautogui.moveTo(1382, 819),pyautogui.click(1382, 819), time.sleep(6)  # caçar boss
    
def time2():
    pyautogui.moveTo(629, 565),pyautogui.click(629, 565), time.sleep(3)  # abrir aba
    pyautogui.moveTo(777, 412), pyautogui.click(777, 412), time.sleep(3)  # selecionar time 2
    pyautogui.moveTo(427, 581), pyautogui.click(427, 581), time.sleep(3)
    pyautogui.moveTo(533, 583), pyautogui.click(533, 583), time.sleep(3)
    pyautogui.moveTo(876, 562),pyautogui.click(876, 562), time.sleep(3)  # fechar aba
    pyautogui.moveTo(1382, 819),pyautogui.click(1382, 819), time.sleep(6)  # caçar boss
def time3():
    pyautogui.moveTo(629, 565),pyautogui.click(629, 565), time.sleep(1)  # abrir aba
    pyautogui.moveTo(672, 579), pyautogui.click(672, 579), time.sleep(1)  # selecionar time 3
    pyautogui.moveTo(773, 584), pyautogui.click(773, 584), time.sleep(1)
    pyautogui.moveTo(430, 751), pyautogui.click(430, 751), time.sleep(1)
    pyautogui.moveTo(876, 562),pyautogui.click(876, 562), time.sleep(1)  # fechar aba
    pyautogui.moveTo(1382, 819),pyautogui.click(1382, 819), time.sleep(6)  # caçar boss
def time4():
    pyautogui.moveTo(629, 565),pyautogui.click(629, 565), time.sleep(3)  # abrir aba
    pyautogui.moveTo(534, 747), pyautogui.click(534, 747), time.sleep(3)  # selecionar time 4
    pyautogui.moveTo(672, 759), pyautogui.click(672, 759), time.sleep(3)
    pyautogui.moveTo(776, 732), pyautogui.click(776, 732), time.sleep(3)
    pyautogui.moveTo(876, 562),pyautogui.click(876, 562), time.sleep(3)  # fechar aba
    pyautogui.moveTo(1382, 819),pyautogui.click(1382, 819), time.sleep(6)  # caçar boss
def time5():
    pyautogui.moveTo(629, 565),pyautogui.click(629, 565), time.sleep(3)  # abrir aba
    pyautogui.moveTo(644, 535), time.sleep(1)
    pyautogui.scroll(-130), time.sleep(1)
    pyautogui.moveTo(435, 815), pyautogui.click(435, 815), time.sleep(3)  # selecionar time 5
    pyautogui.moveTo(563, 799), pyautogui.click(563, 799), time.sleep(3)
    pyautogui.moveTo(673, 815), pyautogui.click(673, 815), time.sleep(3)
    pyautogui.moveTo(876, 562),pyautogui.click(876, 562), time.sleep(3)  # fechar aba
    pyautogui.moveTo(1382, 819),pyautogui.click(1382, 819), time.sleep(6)  # caçar boss
    
def matarboss():
    pyautogui.click(1073, 726), time.sleep(65)
    pyautogui.click(1015, 792), time.sleep(3)
    pyautogui.click(1015, 792), time.sleep(3)
    pyautogui.click(1015, 792), time.sleep(3)

def entrar():
    time.sleep(10), pyautogui.click(1166, 688) #conectar metamask
    time.sleep(8), pyautogui.click(1821, 690) #clicar em assinar
    time.sleep(5), pyautogui.click(585, 486)# clicar em matar boss 
    
def minerar():
    for n in range(4):        
        if contador == 1:
            for a in range(3):                
                time.sleep(5), removerheroinas()
                time.sleep(1), time1()
                time.sleep(1), matarboss()
            contador += 1
        elif contador == 2:
            for a in range(3):                
                time.sleep(5), removerheroinas()
                time.sleep(1), time2()
                time.sleep(1), matarboss()
            contador += 1
        elif contador == 3:
            for a in range(3):
                time.sleep(5), removerheroinas()
                time.sleep(1), time3()
                time.sleep(1), matarboss()
            contador += 1
        elif contador == 4:
            for a in range(3):
                time.sleep(5), removerheroinas()
                time.sleep(1), time4()
                time.sleep(1), matarboss()
            contador += 1        
        elif contador == 5:
            for a in range(3):
                time.sleep(5), removerheroinas()
                time.sleep(1), time5()
                time.sleep(1), matarboss()
            contador += 1
        else:
            pass

def abrirnavegador():
    time.sleep(3), pyautogui.hotkey('win', 'r')
    time.sleep(3), pyautogui.press('enter')
    time.sleep(3), pyautogui.write('cd C:\Program Files\Google\Chrome\Application')
    time.sleep(3), pyautogui.press('enter')
    time.sleep(3), pyautogui.write('chrome.exe --remote-debugging-port=9222 --user-data-dir="D:\Downloads\API\localhost"')
    time.sleep(3), pyautogui.press('enter')
    
def primeiraacc():    
    time.sleep(1), pyautogui.hotkey('win')
    time.sleep(1), pyautogui.write('chrome')
    time.sleep(1), pyautogui.press('enter')
    time.sleep(1), pyautogui.hotkey('win', 'up')
    time.sleep(1), pyautogui.click(1156, 615)
    time.sleep(1), pyautogui.click(1726, 66) #clicar na metamask
    time.sleep(1), pyautogui.write('Mufasa@123')
    time.sleep(1), pyautogui.press('enter')
    time.sleep(1), pyautogui.click(491, 63)
    time.sleep(1), pyautogui.write('https://app.lunarush.io/')
    time.sleep(1), pyautogui.press('enter')

    
                
#######################################################################################################
#1ª conta = LUNA 1 (0xF56676122190fA12F262E357531fB5067016A235) -> email : pedrodpv2@gmail.com
#user1 = 'pedrodpv2@gmail.com'
#senha1 = 'Mufasa@55'

while True:
    contador = 1
    conta = 1
    primeiraacc()   
    time.sleep(20), entrar()
    time.sleep(1), selecionarboss()
    time.sleep(1), minerar()            
    conta += 1
    
    if conta == 2:
        time.sleep(1), pyautogui.click(1848, 66) #clicar no perfil google
        time.sleep(1), pyautogui.click(1580, 533) #SELECIONAR LUNA 2
        time.sleep(1), pyautogui.click(1726, 66) #clicar na metamask
        time.sleep(1), pyautogui.write('Mufasa@123')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(1), pyautogui.click(491, 63)
        time.sleep(1), pyautogui.write('https://app.lunarush.io/')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(20), entrar()
        time.sleep(1), selecionarboss()
        time.sleep(1), minerar()
        pyautogui.hotkey('alt', 'f4')        
        conta += 1
        
    elif conta == 3:
        time.sleep(1), pyautogui.click(1848, 66) #clicar no perfil google
        time.sleep(1), pyautogui.click(1644, 565) #SELECIONAR LUNA 3
        time.sleep(1), pyautogui.click(1726, 66) #clicar na metamask
        time.sleep(1), pyautogui.write('Mufasa@123')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(1), pyautogui.click(491, 63)
        time.sleep(1), pyautogui.write('https://app.lunarush.io/')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(20), entrar()
        time.sleep(1), selecionarboss()
        time.sleep(1), minerar()
        pyautogui.hotkey('alt', 'f4')         
        conta += 1
        
    elif conta == 4:
        time.sleep(1), pyautogui.click(1848, 66) #clicar no perfil google
        time.sleep(1), pyautogui.click(1617, 608) #SELECIONAR LUNA 4
        time.sleep(1), pyautogui.click(1726, 66) #clicar na metamask
        time.sleep(1), pyautogui.write('Mufasa@123')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(1), pyautogui.click(491, 63)
        time.sleep(1), pyautogui.write('https://app.lunarush.io/')
        time.sleep(1), pyautogui.press('enter')
        time.sleep(20), entrar()
        time.sleep(1), selecionarboss()
        time.sleep(1), minerar()
        pyautogui.hotkey('alt', 'f4') 
        conta += 1
        
    else:
        pass
    pyautogui.hotkey('alt', 'f4')
    
#2ª conta = LUNA 2  (0x78BBb8A0bab0a321F709246313Cfe7aA34518599)  -> email : pedrodpv5@gmail.com

#3ª conta = lUNA 3 (0x0498Ec690f8b21dF51735977a5543e82079AB46D) -> email : pedrodpv3@gmail.com

#4ª conta = LUNA 4  (0xb01e6Fb97f538991DA473CA1F75652e9eb8dC591)  -> email : pedrodpv4@gmail.com

#PEGAR POSIÇÃO DO MOUSE
time.sleep(1)
pyautogui.hotkey('alt', 'tab')
time.sleep(1)
###############################

for n in range(3):
    pyautogui.position()
    print(pyautogui.position())
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6376/38535095.py in <module>
#     143     conta = 1
#     144     primeiraacc()
# --> 145     time.sleep(20), entrar()
#     146     time.sleep(1), selecionarboss()
#     147     time.sleep(1), minerar()
#
# KeyboardInterrupt:

# %%
#teste
def primeiraacc():    
    time.sleep(1), pyautogui.hotkey('win')
    time.sleep(1), pyautogui.write('chrome')
    time.sleep(1), pyautogui.press('enter')
    time.sleep(1), pyautogui.hotkey('win', 'up')
    time.sleep(1), pyautogui.click(1156, 615)
    time.sleep(1), pyautogui.click(1726, 66) #clicar na metamask
    time.sleep(1), pyautogui.write('Mufasa@123')
    time.sleep(1), pyautogui.press('enter')
    time.sleep(1), pyautogui.click(491, 63)
    time.sleep(1), pyautogui.write('https://app.lunarush.io/')
    time.sleep(1), pyautogui.press('enter')

primeiraacc()
